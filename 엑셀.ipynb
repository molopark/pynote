# %%
import openpyxl

# %%
wb = openpyxl.Workbook()
ws = wb.worksheets[0]
ws.title = 'ws01'
ws2 = wb.create_sheet('ws02')
ws2['B2'] = 'cell'
filename='test.xlsx'
wb.save(filename)

# %% [markdown]
# # 새 섹션
